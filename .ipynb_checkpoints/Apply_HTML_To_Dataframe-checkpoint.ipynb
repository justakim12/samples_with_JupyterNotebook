# %%
df_final = df_final[['_id', 'classification', 'url', 'thumbnail', 'scanDescription']]
df_final = df_final[0:1500]
#사진들 보여주기
def path_to_image_html(path):
    return '<img src="'+ path + '" style=max-height:200px"/>'
HTML_final = HTML(df_final.to_html(escape=False, formatters=dict(thumbnail=path_to_image_html)))
display(HTML_final)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>classification</th>
#       <th>url</th>
#       <th>thumbnail</th>
#       <th>scanDescription</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5fa9d80822833a5c321e9dc1</td>
#       <td>notReceipt</td>
#       <td>https://myplace-phinf.pstatic.net/20201110_84/1604966404639gqoWt_JPEG/20201110_085634.jpg</td>
#       <td><img src="https://myplace-phinf.pstatic.net/20201110_84/1604966404639gqoWt_JPEG/20201110_085634.jpg" style=max-height:200px"/></td>
#       <td>none_search</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5fa9d81e1094795becb983fc</td>
#       <td>notReceipt</td>
#       <td>https://myplace-phinf.pstatic.net/20201110_62/16049664272004aRTv_JPEG/Screenshot_20201107-200626_KakaoTalk.jpg</td>
# ...
