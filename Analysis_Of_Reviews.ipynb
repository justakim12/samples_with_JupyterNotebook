# %%
## import library
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv(r'Reviews.csv')

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Explore data

# %%
df_r = df.copy()

# %%
## number of reviews
len(df_r)
# Out:
# 568454

# %%
## number of unique authors
df_r.UserId.nunique()
# Out:
# 256059

# %%
## number of unique products
df_r.ProductId.nunique()
# Out:
# 74258

# %%
## Score distribution
df_r.Score.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Explore text

# %%
## calculate length
def customLength(x):
    if x == None:
        return 0
    else:
        return len(x)

# %%
df_r['body_length'] = df_r['Text'].map(lambda x: customLength(x))
df_r.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#
#    body_length
# 0          263
# 1          190
# 2          509
# 3          219
# 4          140

# %%
## Order by desc for body_length
df_r.sort_values('body_length', ascending=False).head()
# Out:
#             Id   ProductId          UserId  \
# 290807  290808  B005HG9ESG  A24HWYHR28JJ7A
# 455393  455394  B005HG9ERW  A24HWYHR28JJ7A
# 496753  496754  B005HG9ET0  A24HWYHR28JJ7A
# 68700    68701  B0051BWU92  A2GZG363BPADYC
# 346183  346184  B002P0Q14C  A1FLQ698D9C0C8
#
#                                              ProfileName  \
# 290807  &#131;&#367;&#142;&#378;&#376; &#969;&#364;&#...
# 455393  &#131;&#367;&#142;&#378;&#376; &#969;&#364;&#...
# 496753  &#131;&#367;&#142;&#378;&#376; &#969;&#364;&#...
# 68700                                       Larry Deemer
# 346183                                          G. Zhang
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 290807                    10                      11      3  1348272000
# 455393                    10                      11      3  1348272000
# 496753                    10                      11      3  1348272000
# 68700                      4                       4      5  1323993600
# 346183                     0                       2      5  1252800000
#
#                                                   Summary  \
# 290807  An okay filtered municipal tap water with slig...
# 455393  An okay filtered municipal tap water with slig...
# 496753  An okay filtered municipal tap water with slig...
# 68700              SEARCHING FOR A PET APPETITE ENHANCER?
# 346183                                   Tea Antioxidants
#
#                                                      Text  body_length
# 290807  Fuzzy Wuzzy's Summary:<br />*** Somewhat recom...        21409
# 455393  Fuzzy Wuzzy's Summary:<br />*** Somewhat recom...        21409
# 496753  Fuzzy Wuzzy's Summary:<br />*** Somewhat recom...        21409
# 68700   **********************************************...        16952
# 346183  Tea Antioxidants<br />----------------<br /><b...        13065

# %%
## Check relation between body_length and Score
df_r.plot.scatter(x='Score', y='body_length', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Score', ylabel='body_length'>

# %% [markdown]
# ## Groupby Product and User

# %%
## Find top10 products with most reviews
df_r_prod_top10 = df_r.groupby('ProductId').size().reset_index(name='review_count').sort_values('review_count', ascending=False).head(10)
df_r_prod_top10
# Out:
#         ProductId  review_count
# 71170  B007JFMH8M           913
# 37898  B0026RQTGE           632
# 42257  B002QWHJOU           632
# 42263  B002QWP89S           632
# 42264  B002QWP8H0           632
# 46205  B003B3OOPA           623
# 28624  B001EO5Q64           567
# 37798  B0026KPDG8           564
# 20497  B000VK8AVK           564
# 68860  B006HYLW32           564

# %%
## Find top10 users who wrote most reviews
df_r_users_top10 = df_r.groupby('UserId').size().reset_index(name='review_count').sort_values('review_count', ascending=False).head(10)
df_r_users_top10
# Out:
#                 UserId  review_count
# 182011  A3OXHLG6DIBRW8           448
# 65586   A1YUL9PCJR3JTY           421
# 252275   AY12DBB0U420B           389
# 82919   A281NPSIMI1C2R           365
# 66162   A1Z54EM24Y40LL           256
# 55736   A1TMAVN4CEM8U8           204
# 110863  A2MUGFV2TDQ47K           201
# 191283  A3TVZM3ZIXG8YW           199
# 183161  A3PJZ8TU8FDQ1K           178
# 238453   AQQLWCMRNDFGI           176

# %% [markdown]
# ## Convert timestamp to datetime

# %%
import datetime

# %%
df_r['changedTime'] = pd.to_datetime(df_r['Time'], unit='s')
df_r.sort_values('changedTime', ascending=False).head()
# Out:
#             Id   ProductId          UserId                        ProfileName  \
# 14783    14784  B000S859NC  A2H7STZ2URUCOE  Christopher Whedon "the odd bead"
# 440485  440486  B002ZOCEMG  A1LIP0F4R542OQ                                  A
# 535436  535437  B001EO5RSQ  A33W5JAFGHYRQZ                ghermine "ghermine"
# 7820      7821  B000HB9TLI  A353IAF5Y1XE53               J. RIGOR "shop mama"
# 146094  146095  B000SDKDM4  A18NG9I9MT2V8I                          Emm "Emm"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 14783                      0                       0      5  1351209600
# 440485                     0                       0      1  1351209600
# 535436                     0                       0      5  1351209600
# 7820                       0                       0      1  1351209600
# 146094                     0                       0      5  1351209600
#
#                      Summary  \
# 14783              GREAT TEA
# 440485                    :(
# 535436     Love this Cereal!
# 7820    Don't like the taste
# 146094          Deeeee-lish!
#
#                                                      Text  body_length  \
# 14783   Rooibos Natural Red tea is something of a pers...          408
# 440485  I just got this coffee a few days ago. I had c...          168
# 535436  There is nothing else like this on the market....          179
# 7820    I do not like sour taste and this has a sour k...          112
# 146094  For far too long I was a devotee of the Starbu...          228
#
#        changedTime
# 14783   2012-10-26
# 440485  2012-10-26
# 535436  2012-10-26
# 7820    2012-10-26
# 146094  2012-10-26
