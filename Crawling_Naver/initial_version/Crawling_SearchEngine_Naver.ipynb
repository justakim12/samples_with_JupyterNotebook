# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
pd.set_option('display.max_colwidth', -1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """

# %% [markdown]
# ## Search specific word in the search engine NAVER and crawl the results

# %%
## Find specific URL
url_front1 = 'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%ED%94%8C%EB%A0%88%EC%9D%B4%EC%8A%A4%20%EB%A6%AC%EB%B7%B0&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start='

url_back1 = '1&refresh_start=0'

news_full1 = pd.DataFrame(columns={"page", "title", "url", "date", "desc"})

## Crawl from page 1-2
for i in range(0,2):
    url_full1 = url_front1 + str(i) + url_back1
    print(i)
    time.sleep(1)
    
    res = requests.get(url_full1)
    soup = BeautifulSoup(res.content, 'html')
    table = soup.find_all('a', {"class": "news_tit"})
    date = soup.find_all('span', {"class": "info"})
    desc = soup.find_all('a', {"class": "api_txt_lines"})
    
    news_full_add1 = pd.DataFrame(columns={"page", "title", "url", "date", "desc"})
    
    page = i
    page_list = []
    number_list = []
    title_list = []
    hyperlink_list = []
    desc_list = []
    date_list = []
    
    for i in range(0, len(table)):
        page_list.append(page)
        number_list.append(i)
        title_list.append(table[i].text) 
        hyperlink_list.append(table[i]['href'])
        desc_list.append(desc[i].text)
        date_list.append(date[i].text)

    news_full_add1['page'] = page_list
    news_full_add1['title'] = title_list
    news_full_add1['url'] = hyperlink_list
    news_full_add1['desc'] = desc_list
    news_full_add1['date'] = date_list
    
    news_full1 = pd.concat([news_full1, news_full_add1])

## organize dataframe
search_word1 = "네이버 플레이스 리뷰"
news_full1['search_word'] = search_word1

news_full1 = news_full1[['search_word', 'page', 'date', 'title', 'desc', 'url']]
news_full1.head()
# Out:
# 0
# 1
#    search_word page         date  \
# 0  네이버 플레이스 리뷰  0    3일 전
# 1  네이버 플레이스 리뷰  0    6일 전
# 2  네이버 플레이스 리뷰  0    7일 전
# 3  네이버 플레이스 리뷰  0    2021.03.26.
# 4  네이버 플레이스 리뷰  0    2021.03.25.
#
#                                               title  \
# 0  '별점테러'에 멍드는 자영업자…'칼 빼든' 네이버 vs '고민중' 배민
# 1  [14F] 네이버의 확 바뀐 리뷰 정책
# 2  영화 '그링고' "인생이 꼬였다! 데이빗 요예로워, 샤를리즈 테론, 아만다 사이...
# 3  네이버서 별점 사라진다…한국마케팅광고협회 "온라인 광고 시장 변화에 적응...
# 4  [IT/과학 주간 핫 이슈] 네이버 실시간 검색 이어 별점 서비스도 종료...정보...
#
#                                                                                                                                     desc  \
# 0  네이버 스마트플레이스 내 리뷰 공간은 리뷰어가 강조되는 '취향 공유 공간'으로 바뀐다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 해당 리뷰어를 구독해 이들 리뷰만 모아볼...
# 1  네이버가 업계 최초로 스마트플레이스 서비스에서 평점 기반의 별점 시스템을 없애겠다고 밝혔습니다. 별점 리뷰 방식 대신에 새로 도입되는 방식이 ‘태그 구름’인데요. 방문자들이 리뷰를 남기면 AI가 핵심 키워드만...
# 2  네이버 영화가 소개하는 영화 <그링고>의 줄거리를 알아보자. 꼬일 대로 꼬인 X 같은 내 인생! 오늘부터... 워>, <다크 플레이스>, <매드맥스: 분노의 도로>, <밀리언 웨이즈>, <프로메테우스>, <스노우 화이트 앤 더 헌츠맨...
# 3  서비스 '스마트플레이스'를 기존 '별점' 방식에서 '태그 구름' 방식으로 개편할 계획을 세워 기업들의 발 빠른 대처가 필요하다. 네이버가 새로 시작하는 태그 구름은 AI가 방문객의 리뷰를 바탕으로 개성을 소개하는...
# 4  네이버는 지난 17일 카페, 식당 등을 노출하는 스마트플레이스 서비스에서 평점 기반 리뷰 시스템을 폐지하고 방문객들의 개인적인 경험 리뷰를 바탕으로 하는 해시태그 형식의 통계 정보를 제공한다고 밝혔다. 해당 개선...
#
#                                                                       url
# 0  http://www.opinionnews.co.kr/news/articleView.html?idxno=48389
# 1  https://imnews.imbc.com/replay/2021/nwtoday/article/6132551_34943.html
# 2  http://www.lecturernews.com/news/articleView.html?idxno=63905
# 3  http://www.kihoilbo.co.kr/news/articleView.html?idxno=918225
# 4  http://www.nextdaily.co.kr/news/article.html?id=20210324800030

# %% [markdown]
# ## Search different word and combine the 2 dataframes

# %%
'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%B3%84%EC%A0%90&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start=11&refresh_start=0'
# Out:
# 'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%B3%84%EC%A0%90&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start=11&refresh_start=0'

# %%
## Find specific URL
url_front2 = 'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%B3%84%EC%A0%90&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start='

url_back2 = '1&refresh_start=0'

news_full2 = pd.DataFrame(columns={"page", "title", "url", "date", "desc"})

## Crawl from page 1-2
for i in range(0,2):
    url_full2 = url_front2 + str(i) + url_back2
    print(i)
    time.sleep(1)
    
    res = requests.get(url_full2)
    soup = BeautifulSoup(res.content, 'html')
    table = soup.find_all('a', {"class": "news_tit"})
    date = soup.find_all('span', {"class": "info"})
    desc = soup.find_all('a', {"class": "api_txt_lines"})
    
    news_full_add2 = pd.DataFrame(columns={"page", "title", "url", "date", "desc"})
    
    page = i
    page_list = []
    number_list = []
    title_list = []
    hyperlink_list = []
    desc_list = []
    date_list = []
    
    for i in range(0, len(table)):
        page_list.append(page)
        number_list.append(i)
        title_list.append(table[i].text) 
        hyperlink_list.append(table[i]['href'])
        desc_list.append(desc[i].text)
        date_list.append(date[i].text)

    news_full_add2['page'] = page_list
    news_full_add2['title'] = title_list
    news_full_add2['url'] = hyperlink_list
    news_full_add2['desc'] = desc_list
    news_full_add2['date'] = date_list
    
    news_full2 = pd.concat([news_full2, news_full_add2])
    
## organize dataframe
search_word2 = "네이버 별점"
news_full2['search_word'] = search_word2

news_full2 = news_full2[['search_word', 'page', 'date', 'title', 'desc', 'url']]
news_full2.head()
# Out:
# 0
# 1
#   search_word page   date                                            title  \
# 0  네이버 별점      0    1시간 전  [종합] '스트레이트' 쿠팡의 배신, 소상공인 정산 늦어 "배달료도 삭감"
# 1  네이버 별점      0    1일 전   [後스토리]'좋아요'와 '싫어요'가 사라진다…'따봉'의 역설
# 2  네이버 별점      0    3일 전   [e글중심] “야외 주류 광고판 없앤다고 술 덜 마실까?”
# 3  네이버 별점      0    3일 전   '별점테러'에 멍드는 자영업자…'칼 빼든' 네이버 vs '고민중' 배민
# 4  네이버 별점      0    3일 전   식당 별점 테러, 이대로 괜찮을까요? "1인분 시켰는데 1인분만 왔으니 별 1개...
#
#                                                                                                                                  desc  \
# 0  게다가 정 씨가 판매했던 상품의 별점과 리뷰, 문의와 답변 또한 전부 새 판매자에게 넘어가 있었다.... 쿠팡은 전자상거래 입지에서 현재 네이버를 바짝 쫓고 있다. 이렇게 빠른 추격이 가능했던 건 로켓배송. 최근 2-3년...
# 1  ◇국내에서는 네이버 별점 폐지…'상생' 강조 국내에서는 네이버가 별점 평가를 없앤다고 선언했다. '별점 테러'로 소상공인이 애꿎은 피해를 보는 상황을 막겠다는 의도다. 앞선 사례들과 조금 결이 다르지만, 이용자...
# 2  * 어제의 e 글 중심 ▷ "박원순 떠올리게 해서"···'선거 왜 하죠'가 법 위반이란 선관위 #네이버 블랙핑크... 네이트판 〈카카오 택시 별점이 낮은 이유〉 2. 오늘의유머 〈엄마의 실수로 지하철에 남겨진 아기〉 3....
# 3  사진은 네이버 가게 별점 사진. 내용과 관계 없음. 사진=네이버 캡처  69만 명이 넘게 가입해있는 국내 최대 규모 자영업자 온라인 커뮤니티에는 '별점테러'에 대한 게시물을 쉽게 찾아볼 수 있다. '별점의 노예라 한숨만...
# 4  게다가 최근 음식점을 평가하는 별점 리뷰도 사라진다는 얘기가 나오면서 정보를 빠르고 편리하게 얻을 수... ◆ 전민기: 자유한국당 김성태 의원이 조사한 건데, 2019년 9월 1일부터 19일까지 매일 오후 3시 기준 네이버 실검...
#
#                                                                  url
# 0  http://www.topstarnews.net/news/articleView.html?idxno=869550
# 1  https://www.news1.kr/articles/?4262591
# 2  https://news.joins.com/article/olink/23620562
# 3  http://www.opinionnews.co.kr/news/articleView.html?idxno=48389
# 4  https://radio.ytn.co.kr/program/?f=2&id=75825&s_mcd=0433&s_hcd=01

# %%
## Combine the 2 dataframes
news_full_combined = pd.concat([news_full1, news_full2])

# %%
len(news_full_combined)
# Out:
# 40

# %%
news_full_combined
# Out:
#    search_word page         date  \
# 0  네이버 플레이스 리뷰  0    3일 전
# 1  네이버 플레이스 리뷰  0    6일 전
# 2  네이버 플레이스 리뷰  0    7일 전
# 3  네이버 플레이스 리뷰  0    2021.03.26.
# 4  네이버 플레이스 리뷰  0    2021.03.25.
# 5  네이버 플레이스 리뷰  0    2021.03.24.
# 6  네이버 플레이스 리뷰  0    2021.03.22.
# 7  네이버 플레이스 리뷰  0    2021.03.22.
# 8  네이버 플레이스 리뷰  0    2021.03.21.
# 9  네이버 플레이스 리뷰  0    2021.03.19.
# 0  네이버 플레이스 리뷰  1    2021.03.19.
# 1  네이버 플레이스 리뷰  1    2021.03.19.
# 2  네이버 플레이스 리뷰  1    2021.03.18.
# 3  네이버 플레이스 리뷰  1    A27면 TOP
# 4  네이버 플레이스 리뷰  1    2021.03.18.
# 5  네이버 플레이스 리뷰  1    2021.03.18.
# 6  네이버 플레이스 리뷰  1    2021.03.18.
# 7  네이버 플레이스 리뷰  1    2021.03.18.
# 8  네이버 플레이스 리뷰  1    20면 1단
# 9  네이버 플레이스 리뷰  1    2021.03.18.
# 0  네이버 별점       0    1시간 전
# 1  네이버 별점       0    1일 전
# 2  네이버 별점       0    3일 전
# 3  네이버 별점       0    3일 전
# 4  네이버 별점       0    3일 전
# 5  네이버 별점       0    3일 전
# 6  네이버 별점       0    4일 전
# 7  네이버 별점       0    4일 전
# 8  네이버 별점       0    4일 전
# 9  네이버 별점       0    5일 전
# 0  네이버 별점       1    5일 전
# 1  네이버 별점       1    5일 전
# 2  네이버 별점       1    5일 전
# 3  네이버 별점       1    5일 전
# 4  네이버 별점       1    5일 전
# 5  네이버 별점       1    5일 전
# 6  네이버 별점       1    5일 전
# 7  네이버 별점       1    5일 전
# 8  네이버 별점       1    5일 전
# 9  네이버 별점       1    5일 전
#
#                                               title  \
# 0  '별점테러'에 멍드는 자영업자…'칼 빼든' 네이버 vs '고민중' 배민
# 1  [14F] 네이버의 확 바뀐 리뷰 정책
# 2  영화 '그링고' "인생이 꼬였다! 데이빗 요예로워, 샤를리즈 테론, 아만다 사이...
# 3  네이버서 별점 사라진다…한국마케팅광고협회 "온라인 광고 시장 변화에 적응...
# 4  [IT/과학 주간 핫 이슈] 네이버 실시간 검색 이어 별점 서비스도 종료...정보...
# 5  한성숙 대표 "리뷰 구조에 책임감 있게 고민해 새로운 툴 선보일 것"
# 6  “맛있게 드셨으면 별점 1점” 배달 사장님 황당한 ‘역발상’
# 7  “별점 폐지 역풍! 파워리뷰어 등장?”…덜덜 떠는 식당 사장님
# 8  식당·카페 별점 없애는 네이버…배달앱 업체들은 현 제도 유지 중
# 9  '네이버 별점' 시스템 종료... 새로운 '태그 구름'이 사용자 사업자 모두 잡을...
# 0  데이트 하기 좋은 광교의 가볼 만한 곳 4
# 1  네이버, 악성리뷰 등 자영업자 두 번 울리는 ‘식당 별점’ 없앤다
# 2  네이버 별점 시스템 폐지...리뷰 환경 개선
# 3  '악성 리뷰' '별점 테러' 갑질에 사장님들은 웁니다
# 4  네이버 음식점 리뷰 폐지에…"불친절·위생불량 어떻게 거르지?"
# 5  네이버, 식당 ‘별점’ 개편에 누리꾼 황당...“과도한 조치”
# 6  동네 식당 울리는 네이버 '별점' 퇴출에 외식업계 '환영'
# 7  네이버, 식당 별점 없애고 취향 담은 ‘태그 구름’ 도입
# 8  네이버, '별점 평가' 없앤다… AI기반 '태그 구름'으로 전환
# 9  네이버에선 식당 ‘별점테러’ 없어진다…키워드 형식의 ‘태그 구름’이 대체
# 0  [종합] '스트레이트' 쿠팡의 배신, 소상공인 정산 늦어 "배달료도 삭감"
# 1  [後스토리]'좋아요'와 '싫어요'가 사라진다…'따봉'의 역설
# 2  [e글중심] “야외 주류 광고판 없앤다고 술 덜 마실까?”
# 3  '별점테러'에 멍드는 자영업자…'칼 빼든' 네이버 vs '고민중' 배민
# 4  식당 별점 테러, 이대로 괜찮을까요? "1인분 시켰는데 1인분만 왔으니 별 1개...
# 5  식당 별점 테러, 이대로 괜찮을까요? "1인분 시켰는데 1인분만 왔으니 별 1개...
# 6  “노랑머리 아줌마 무서워, 별점 테러!” 황당 배달 음식 리뷰 천태만상
# 7  네이버 ‘별점 리뷰’ 폐지 논란, “고객 갑질 막기 위해” VS “좋은 정보”
# 8  수도권 집중 심화, 인구·생산 절반 넘었다
# 9  인기 웹툰 원작 '아이들은 즐겁다' 5월 개봉[공식]
# 0  “표현의 자유?” 웹툰 속 등장인물 대사, 네티즌들 논쟁 붙었다
# 1  '아이들은 즐겁다' 5월 개봉 확정, 1차 포스터·예고편 공개
# 2  [공식]"네이버 인기 웹툰 원작"…'아이들은 즐겁다', 5월 개봉 확정
# 3  인기 웹툰 영화화한 '아이들은 즐겁다' 예고편 공개
# 4  네이버 웹툰 원작 ‘아이들은 즐겁다’, 5월 개봉 확정
# 5  네이버 웹툰 원작 '아이들은 즐겁다', 5월 극장 개봉
# 6  네이버 웹툰 원작 ‘아이들은 즐겁다’, 5월 개봉 확정..전지적 어린이 시점
# 7  절로 엄마미소 짓게 되는 '아이들은 즐겁다', 봄기운 가득한 1차 예고편
# 8  웹툰 원작 '아이들은 즐겁다', 5월 개봉 확정
# 9  웹툰 원작 영화 ‘아이들은 즐겁다’ 5월 개봉 확정 [공식]
#
#                                                                                                                                     desc  \
# 0  네이버 스마트플레이스 내 리뷰 공간은 리뷰어가 강조되는 '취향 공유 공간'으로 바뀐다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 해당 리뷰어를 구독해 이들 리뷰만 모아볼...
# 1  네이버가 업계 최초로 스마트플레이스 서비스에서 평점 기반의 별점 시스템을 없애겠다고 밝혔습니다. 별점 리뷰 방식 대신에 새로 도입되는 방식이 ‘태그 구름’인데요. 방문자들이 리뷰를 남기면 AI가 핵심 키워드만...
# 2  네이버 영화가 소개하는 영화 <그링고>의 줄거리를 알아보자. 꼬일 대로 꼬인 X 같은 내 인생! 오늘부터... 워>, <다크 플레이스>, <매드맥스: 분노의 도로>, <밀리언 웨이즈>, <프로메테우스>, <스노우 화이트 앤 더 헌츠맨...
# 3  서비스 '스마트플레이스'를 기존 '별점' 방식에서 '태그 구름' 방식으로 개편할 계획을 세워 기업들의 발 빠른 대처가 필요하다. 네이버가 새로 시작하는 태그 구름은 AI가 방문객의 리뷰를 바탕으로 개성을 소개하는...
# 4  네이버는 지난 17일 카페, 식당 등을 노출하는 스마트플레이스 서비스에서 평점 기반 리뷰 시스템을 폐지하고 방문객들의 개인적인 경험 리뷰를 바탕으로 하는 해시태그 형식의 통계 정보를 제공한다고 밝혔다. 해당 개선...
# 5  이에, 네이버는 스마트플레이스 내 리뷰 공간을 리뷰어가 강조되는 '취향 공유의 공간'으로 탈바꿈한다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 리뷰어를 '구독'해 이들의...
# 6  네이버는 최근 스마트플레이스에서 평점 기반 리뷰 시스템을 폐지하고 해시태그 형식의 통계 정보를 선보이겠다고 밝힌 바 있다. 배달의민족은 악성 리뷰에 대해 자영업자가 요청하면 30일 동안 게시를 중단하는 시스템을...
# 7  지난 17일 네이버는 스마트플레이스에서 평점 기반 리뷰 시스템을 폐지하고 방문객들의 리뷰를 바탕으로 하는 해시태그 형식의 통계 정보를 선보이겠다고 밝혔다. 기존 가게에 대한 리뷰가 별점과 짧은 코멘트를 중심으로...
# 8  앞서 지난 17일 네이버는 오는 3분기까지 스마트플레이스 서비스에서 평점 기반 리뷰 시스템을 없애고 방문객들 리뷰를 토대로 해시태그 형식의 통계 정보를 선보인다는 계획을 발표했다. 별점을 없애는 대신 인공지능(AI)...
# 9  이처럼 사업자와 더불어 사용자들의 불만까지 보완하기 위해 네이버는 스마트 플레이스 내 리뷰 공간을 리뷰어가 강조되는 '취향 공유의 공간'으로 개선할 계획이다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를...
# 0  핫플레이스로 떠오르고 있다. 210여 종의 해양 생물 3만 마리를 만나볼 수 있고 터널 수조와 미끄럼틀을 탈... 네이버 예약을 통해서 방문 후 리뷰를 남기면 냉면 또는 한우 눈꽃 육회를 서비스로 주는 이벤트도 진행...
# 1  이에 네이버는 스마트플레이스 내 리뷰 공간을 리뷰어가 강조되는 ‘취향 공유의 공간’으로 탈바꿈한다고 알렸다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 리뷰어를...
# 2  이에 네이버는 스마트플레이스 내 리뷰 공간을 리뷰어가 강조되는 '취향 공유의 공간'으로 탈바꿈한다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 리뷰어를 '구독'해 이들의...
# 3  악성 리뷰 근절 방안을 내세우고 있다. 네이버는 지난 17일 식당·카페 등 네이버에 업체 정보를 제공하는 ‘스마트플레이스’에 별점 평가를 없애겠다고 밝혔다. 배달의민족은 자영업자가 요청하면 일시적으로 리뷰를...
# 4  5 이상, 실패 확률 적었다" 18일 정보통신(IT) 업계에 따르면 네이버는 오는 3분기까지 스마트플레이스 서비스에서 평점 기반 리뷰 시스템을 폐지하고 방문객들 리뷰를 바탕으로 하는 해시태그 형식의 통계 정보를 선보일...
# 5  네이버는 지난 17일 지역정보 서비스인 ‘스마트플레이스’에 포함된 리뷰의 역할을 재정의하겠다고 밝혔다. 현재 별점과 약간의 코멘트가 섞인 리뷰 체계에서 업체의 성격을 나타내는 태그를 자동적으로 띄우는 방식으로...
# 6  이에, 네이버는 스마트플레이스 내 리뷰 공간을 리뷰어가 강조되는 취향 공유의 공간으로 탈바꿈시킬 계획이다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있고, 리뷰어를 '구독'해 이들의...
# 7  네이버는 스마트플레이스 서비스에서 평점 기반 리뷰 시스템을 폐지하고 방문객 리뷰를 바탕으로 하는 해시태그 형식 통계 정보를 신설한다고 17일 밝혔다. 네이버는 별점 시스템이 특히 지역 중소상공인(SME)에게...
# 8  이에, 네이버는 스마트플레이스 내 리뷰 공간을 리뷰어가 강조되는 '취향 공유의 공간'으로 탈바꿈한다. 사용자는 나와 맛집 취향이 비슷한 리뷰어의 리뷰를 우선적으로 확인할 수 있게 되고, 리뷰어를 '구독'해 이들의...
# 9  네이버는 자사의 ‘스마트플레이스’ 서비스에서 평점 기반 리뷰 시스템을 폐지하고 방문객들 리뷰를 기초로 해시태그 형식의 통계 정보를 신설한다고 17일 밝혔다. 이에 따라 앞으로는 특정 장소의 방문객들이 리뷰를...
# 0  게다가 정 씨가 판매했던 상품의 별점과 리뷰, 문의와 답변 또한 전부 새 판매자에게 넘어가 있었다.... 쿠팡은 전자상거래 입지에서 현재 네이버를 바짝 쫓고 있다. 이렇게 빠른 추격이 가능했던 건 로켓배송. 최근 2-3년...
# 1  ◇국내에서는 네이버 별점 폐지…'상생' 강조 국내에서는 네이버가 별점 평가를 없앤다고 선언했다. '별점 테러'로 소상공인이 애꿎은 피해를 보는 상황을 막겠다는 의도다. 앞선 사례들과 조금 결이 다르지만, 이용자...
# 2  * 어제의 e 글 중심 ▷ "박원순 떠올리게 해서"···'선거 왜 하죠'가 법 위반이란 선관위 #네이버 블랙핑크... 네이트판 〈카카오 택시 별점이 낮은 이유〉 2. 오늘의유머 〈엄마의 실수로 지하철에 남겨진 아기〉 3....
# 3  사진은 네이버 가게 별점 사진. 내용과 관계 없음. 사진=네이버 캡처  69만 명이 넘게 가입해있는 국내 최대 규모 자영업자 온라인 커뮤니티에는 '별점테러'에 대한 게시물을 쉽게 찾아볼 수 있다. '별점의 노예라 한숨만...
# 4  게다가 최근 음식점을 평가하는 별점 리뷰도 사라진다는 얘기가 나오면서 정보를 빠르고 편리하게 얻을 수... ◆ 전민기: 자유한국당 김성태 의원이 조사한 건데, 2019년 9월 1일부터 19일까지 매일 오후 3시 기준 네이버 실검...
# 5  게다가 최근 음식점을 평가하는 별점 리뷰도 사라진다는 얘기가 나오면서 정보를 빠르고 편리하게 얻을 수... ◆ 전민기: 자유한국당 김성태 의원이 조사한 건데, 2019년 9월 1일부터 19일까지 매일 오후 3시 기준 네이버 실검...
# 6  네이버는 최근 네이버 영수증에 있는 평점 기반의 ‘별점 시스템’을 없앴다. 반면 배달의민족, 요기요, 쿠팡이츠 등 주요 배달 플랫폼업체들은 별점 폐지에 부정적이다. 대신 악성 리뷰 노출을 막는 등 개선책으로...
# 7  네이버 ‘별점 리뷰’ 폐지 논란 별점별 모양의 점수를 표시한 것으로 별의 숫자 또는 별 모양의 안쪽을 진하게 채운 정도로 점수를 매긴다. 별 다섯 개가 다 채워져 있으면 5점, 하나도 안 채워져 있으면 0점이다. 별점...
# 8  전문가들의 평균점수(별점, 5개 만점)는 2.66개(28명 응답). 절반의 성공이다. 다행히 촛불 정부엔 “아직... 동행할 여러분을 기다립니다. [▶네이버 채널 구독하기] [▶후원 하기][▶디지털성범죄 아카이브 '너머n' 들어가기]
# 9  네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화 개봉 소식과 함께 공개한 1차 포스터와 예고편은 봄의 기운마저 한아름 안겨준다. 영화 속 주인공인 다이와 민호(박예찬), 유진(홍정민)이가 푸른...
# 0  네이버 웹툰 '바른 연애 길잡이'의 한 장면을 두고 때아닌 논쟁이 일었다.지난 29일 연재된 '바른 연애 길잡이... 같은 날 더쿠의 경우 "창조적인 논란", "허버의 경우는 허겁지겁 논란으로 쓰는 경우도 많다", "저거에 별점테...
# 1  다이와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 '아이들은 즐겁다'는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게 탄생하게...
# 2  다이와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 '아이들은 즐겁다'는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게 탄생하게...
# 3  웹툰 '아이들은 즐겁다'는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 받았다. 1차 포스터는 영화 속 다이와 민호(박예찬), 유진(홍정민)이가 푸른 하늘을 배경으로 점프하고 있는 뒷모습을 담았다. 여기에 'WE’RE SO...
# 4  다이와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 ‘아이들은 즐겁다’는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게...
# 5  다이와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 웹툰 '아이들은 즐겁다'는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 재탄생하게...
# 6  즐겁다’는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게 탄생하게 된 <아이들은 즐겁다>는 원작이 가진 깊은 감동과 여운을 고스란히...
# 7  ‘다이’와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 [아이들은 즐겁다]는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게...
# 8  다이와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 '아이들은 즐겁다'는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게 탄생하게...
# 9  ‘다이’와 친구들의 눈으로 바라본 세상을 담담한 그림체와 예리하지만 따뜻한 시선으로 담아내 감동을 안겨준 [아이들은 즐겁다]는 네이버 웹툰에서 평균 9.95점의 기록적인 별점을 남긴 바 있다. 영화로 새롭게...
#
#                                                                                         url
# 0  http://www.opinionnews.co.kr/news/articleView.html?idxno=48389
# 1  https://imnews.imbc.com/replay/2021/nwtoday/article/6132551_34943.html
# 2  http://www.lecturernews.com/news/articleView.html?idxno=63905
# 3  http://www.kihoilbo.co.kr/news/articleView.html?idxno=918225
# 4  http://www.nextdaily.co.kr/news/article.html?id=20210324800030
# 5  http://www.dailysportshankook.co.kr/news/articleView.html?idxno=238313
# 6  http://news.heraldcorp.com/view.php?ud=20210322001091
# 7  http://news.heraldcorp.com/view.php?ud=20210322001078
# 8  http://www.newstomato.com/ReadNews.aspx?no=1032301
# 9  http://www.civicnews.com/news/articleView.html?idxno=31224
# 0  http://www.esquirekorea.co.kr/article/53818
# 1  http://www.segye.com/content/html/2021/03/17/20210317506907.html?OutUrl=naver
# 2  http://www.wsobi.com/news/articleView.html?idxno=116315
# 3  http://www.edaily.co.kr/news/newspath.asp?newsid=03342326628984632
# 4  https://www.hankyung.com/it/article/202103187334g
# 5  http://theviewers.co.kr/View.aspx?No=1534855
# 6  http://www.foodnews.co.kr/news/articleView.html?idxno=91572
# 7  https://www.seoul.co.kr/news/newsView.php?id=20210318020016&wlog_tag3=naver
# 8  http://www.kbiznews.co.kr/news/articleView.html?idxno=79152
# 9  https://www.seoul.co.kr/news/newsView.php?id=20210317500195&wlog_tag3=naver
# 0  http://www.topstarnews.net/news/articleView.html?idxno=869550
# 1  https://www.news1.kr/articles/?4262591
# 2  https://news.joins.com/article/olink/23620562
# 3  http://www.opinionnews.co.kr/news/articleView.html?idxno=48389
# 4  https://radio.ytn.co.kr/program/?f=2&id=75825&s_mcd=0433&s_hcd=01
# 5  https://www.ytn.co.kr/_ln/0103_202104011202195051
# 6  http://news.heraldcorp.com/view.php?ud=20210331001123
# 7  http://kids.donga.com/news/vv.php?type=news&id=20210331124339164358
# 8  http://h21.hani.co.kr/arti/society/society_general/50135.html
# 9  http://star.mk.co.kr/new/view.php?mc=ST&year=2021&no=303205
# 0  https://www.wikitree.co.kr/articles/633576
# 1  http://stoo.asiae.co.kr/article.php?aid=71260220140
# 2  http://sports.chosun.com/news/ntype.htm?id=202103300100233930015119&servicedate=20210330
# 3  http://www.newsis.com/view/?id=NISX20210330_0001388646&cID=10601&pID=10600
# 4  http://www.theceluv.com/article.php?aid=1617083194371530011
# 5  http://www.osen.co.kr/article/G1111548427
# 6  http://www.breaknews.com/795844
# 7  http://hobbyen.co.kr/news/newsview.php?ncode=1065588488785125
# 8  http://isplus.live.joins.com/news/article/article.asp?total_id=24023735
# 9  https://sports.donga.com/article/all/20210330/106154186/1
