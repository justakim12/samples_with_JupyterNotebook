# %%
from crawling import Crawl
import pandas as pd

# %%
search_word = '네이버 플레이스 리뷰'
url_front = 'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%ED%94%8C%EB%A0%88%EC%9D%B4%EC%8A%A4%20%EB%A6%AC%EB%B7%B0&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start='
url_back = '1&refresh_start=0'
crawling_pages = int(4)

crawl_1 = Crawl(search_word, url_front, url_back, crawling_pages)
df_1 = crawl_1.crawl_website()
df_1.head()
# Out:
# 0
#    search_word page         date  \
# 0  네이버 플레이스 리뷰    4         1일 전
# 1  네이버 플레이스 리뷰    4         7일 전
# 2  네이버 플레이스 리뷰    4       14면 1단
# 3  네이버 플레이스 리뷰    4  2021.09.29.
# 4  네이버 플레이스 리뷰    4  2021.09.27.
#
#                                            title  \
# 0                         경주 황금십원빵, 서울에서 커피를 만나다
# 1  중고거래 하러 왔다가 위로 받고 간다…할머니부터 손자까지 ‘1일 1당근’ 시...
# 2               '별점 폐지' 파격 발상…네이버 비밀병기 MZ세대 기획자들
# 3           리뷰 한줄에 울고 웃고…악성 리뷰글 삭제 방법은? [박용선 칼럼]
# 4   [별점공화국]④ 카카오맵은 별점 테러의 온상… 뒷짐 진 플랫폼에 자영업자만...
#
#                                                 desc  \
# 0  있으며, 네이버 “MY 플레이스”에서 황금십원빵을 결제한 영수증을 찍어 제출하고 황...
# 1  네이버, 카카오, 라인, 쿠팡, 배달의민족, 당근마켓, 토스 등 성공한 스타트업을 ...
# 2  (27)씨와 네이버 플레이스의 기획자 김지수씨(34)다. 스테이션제로는 한성숙 네이...
# 3  네이버 지도, 네이버플레이스, 영수증 리뷰, 카카오 지도 리뷰 모두 마찬가지다. 허...
# 4  이융성 네이버 플레이스 리뷰 팀 책임리더는 별점 리뷰를 없애기로 한 이유에 대해 “...
#
#                                                  url
# 0  http://mbnmoney.mbn.co.kr/news/view?news_no=MM...
# ...

# %%
len(df_1)
# Out:
# 10

# %%
search_word = "네이버 별점"
url_front = 'https://search.naver.com/search.naver?&where=news&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%B3%84%EC%A0%90&sm=tab_pge&sort=1&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:dd,p:all,a:all&mynews=0&start='
url_back = '1&refresh_start=0'
crawling_pages = 3

crawl_2 = Crawl(search_word, url_front, url_back, crawling_pages)
df_2 = crawl_2.crawl_website()
df_2.head()
# Out:
# 0
#   search_word page    date                                         title  \
# 0      네이버 별점    0   7시간 전  [이은주의 스타트업픽] 틱톡·티몬·아프리카tv 손잡은 커머스 콘텐츠 스타트...
# 1      네이버 별점    0  19시간 전                  플랫폼 분쟁조정 신청 5년간 177건…쿠팡이 60%
# 2      네이버 별점    0  20시간 전                      플랫폼 분쟁조정 10건 중 6건은 쿠팡 관련
# 3      네이버 별점    0  21시간 전                플랫폼 분쟁조정 신청 61%가 쿠팡 관련…카카오의 8배
# 4      네이버 별점    0  22시간 전                       플랫폼 분쟁조정 신청의 61%가 쿠팡 관련
#
#                                                 desc  \
# 0  비대면 시대가 부상하면서 유통기업뿐 아니라 네이버와 틱톡, 아프라카TV 같은 플랫폼...
# 1  같은 기간 네이버는 36건, 배달의 민족 18건, 카카오 14건으로, 네이버와 배달...
# 2  특히 네이버와 배달의민족은 중소벤처기업부의 '자상한기업'으로 선정돼 인센티브를 받는...
# 3  특히 네이버와 배달의민족은 중소벤처기업부의 '자상한 기업'으로 선정돼 인센티브를 받...
# 4  네이버와 배달의민족은 역량과 노하우 등을 소상공인과 공유하는  '자상한기업'으로 선...
#
#                                                  url
# 0  http://it.chosun.com/site/data/html_dir/2021/1...
# 1  http://www.yonhapnewstv.co.kr/MYH2021100701640...
# ...

# %%
search_word = "플레이스 키워드 리뷰"
url_front = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%94%8C%EB%A0%88%EC%9D%B4%EC%8A%A4%20%ED%82%A4%EC%9B%8C%EB%93%9C%20%EB%A6%AC%EB%B7%B0&sort=1&photo=0&field=0&pd=0&ds=&de=&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:all,a:all&start='
url_back = '1&refresh_start=0'
crawling_pages = 3

crawl_3 = Crawl(search_word, url_front, url_back, crawling_pages)
df_3 = crawl_3.crawl_website()
df_3.head()
# Out:
# 0
#    search_word page         date  \
# 0  플레이스 키워드 리뷰    0      B1면 TOP
# 1  플레이스 키워드 리뷰    0  2021.09.30.
# 2  플레이스 키워드 리뷰    0       14면 1단
# 3  플레이스 키워드 리뷰    0  2021.09.29.
# 4  플레이스 키워드 리뷰    0  2021.09.23.
#
#                                                title  \
# 0  [Biz times] 누구나 가르칠수 있다 무엇이든 배울수 있다…유데미가 그런 학교...
# 1                   '별점 폐지' 파격 발상…네이버 비밀병기 MZ세대 기획자들
# 2       [별점공화국]④ 카카오맵은 별점 테러의 온상… 뒷짐 진 플랫폼에 자영업자만...
# 3           네이버 '키워드리뷰' 확대 적용...소상공인 매장 '악성리뷰' 논란 억제
# 4              정가는 21만원인데...'사인 들어간 한정판' 1400만원에 팔린다
#
#                                                 desc  \
# 0  또 학생들은 직접 유데미를 검색하거나 혹은 유데미가 제공하는 방대한 강의 주제를 키...
# 1  조만간 키워드 리뷰 도입을 시작하고, 내년 1분기 내로 네이버에서 별점 리뷰는 사라...
# 2  키워드 리뷰는 별점 대신 이용자가 가게의 장점과 특징을 보여주는 키워드를 골라서 리...
# 3  키워드리뷰는 스마트플레이스에 연동한 매장 평가 시스템이다. 이용자가 직접 리뷰를 작...
# 4  이 한정판 신발 역시 당첨자 발표 전부터 카페와 블로그에서 핫 키워드로 떠오르며 인...
#
#                                                  url
# 0  http://news.mk.co.kr/newsRead.php?no=928227&ye...
# ...

# %%
df_combined = pd.concat([df_1, df_2, df_3])
len(df_combined)
# Out:
# 30

# %%
df_combined.head()
# Out:
#    search_word page         date  \
# 0  네이버 플레이스 리뷰    0         1일 전
# 1  네이버 플레이스 리뷰    0         7일 전
# 2  네이버 플레이스 리뷰    0       14면 1단
# 3  네이버 플레이스 리뷰    0  2021.09.29.
# 4  네이버 플레이스 리뷰    0  2021.09.27.
#
#                                            title  \
# 0                         경주 황금십원빵, 서울에서 커피를 만나다
# 1  중고거래 하러 왔다가 위로 받고 간다…할머니부터 손자까지 ‘1일 1당근’ 시...
# 2               '별점 폐지' 파격 발상…네이버 비밀병기 MZ세대 기획자들
# 3           리뷰 한줄에 울고 웃고…악성 리뷰글 삭제 방법은? [박용선 칼럼]
# 4   [별점공화국]④ 카카오맵은 별점 테러의 온상… 뒷짐 진 플랫폼에 자영업자만...
#
#                                                 desc  \
# 0  있으며, 네이버 “MY 플레이스”에서 황금십원빵을 결제한 영수증을 찍어 제출하고 황...
# 1  네이버, 카카오, 라인, 쿠팡, 배달의민족, 당근마켓, 토스 등 성공한 스타트업을 ...
# 2  (27)씨와 네이버 플레이스의 기획자 김지수씨(34)다. 스테이션제로는 한성숙 네이...
# 3  네이버 지도, 네이버플레이스, 영수증 리뷰, 카카오 지도 리뷰 모두 마찬가지다. 허...
# 4  이융성 네이버 플레이스 리뷰 팀 책임리더는 별점 리뷰를 없애기로 한 이유에 대해 “...
#
#                                                  url
# 0  http://mbnmoney.mbn.co.kr/news/view?news_no=MM...
# ...

# %%
df_combined.tail()
# Out:
#    search_word page         date                                      title  \
# 5  플레이스 키워드 리뷰    0      16면 TOP     대개협 "개원 60%, 리뷰 피해"…네이버 "어뷰징 대응 계속 강화"
# 6  플레이스 키워드 리뷰    0  2021.09.15.  [IT돋보기] '새우튀김 갑질' 다시 불거진 '악성 리뷰'…배달앱 '대응'
# 7  플레이스 키워드 리뷰    0      C1면 TOP               네이버 키워드 리뷰, 미용·숙박 업종으로 범위 확대
# 8  플레이스 키워드 리뷰    0  2021.09.01.      네이버, 미용실·게스트하우스 리뷰에도 '별점' 대신 '키워드 리뷰'
# 9  플레이스 키워드 리뷰    0  2021.08.20.                    네이버 키워드 리뷰, 미용·숙박까지 넓힌다
#
#                                                 desc  \
# 5  영수증 리뷰 (출처=네이버 마이플레이스) 네이버는 대개협의 설문조사 결과에 공식적인...
# 6  네이버 플레이스처럼 아예 별점 자체를 없애는 플랫폼도 있다. 네이버는 지난달 8일 ...
# 7  특히 키워드 리뷰는 그 결과가 아직 플레이스 페이지에 반영되지 않았음에도 이미 사용...
# 8  이융성 네이버 MY플레이스 책임리더는 "키워드 리뷰의 대상 업종을 순차 확대하며 플...
# 9  네이버 MY플레이스 이융성 책임리더는 “키워드 리뷰의 대상 업종을 순차 확대하며 플...
#
#                                                  url
# 5        https://zdnet.co.kr/view/?no=20210820161355
# 6                http://www.inews24.com/view/1396626
# ...
